# %%
import math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import tensorflow_probability as tfp

from training import create_models
from models import Model, DefaultDenseModel, DefaultConvModel, McDropoutModel, BayesByBackpropModel
import commons
# Out:
# Tensorflow Version: 2.0.0-beta1
# Tensorflow Probability Version: 0.8.0-dev20190619
# Found GPU: /device:GPU:0

# %%
dataset_size = 1.0
embedding_dim = 50
words_per_sentence = 2800
batch_size = 128
epochs = 50

glove_dir = "D:/google drive/haw/master/mastertheisis/hauptprojekt/glove"
history_evaluation_folder = "D:/google drive/haw/master/mastertheisis/hauptprojekt/evaluation/history/"
models_dir = "D:/google drive/haw/master/mastertheisis/hauptprojekt/training/models"
history_dir = "D:/google drive/haw/master/mastertheisis/hauptprojekt/training/history"

setup = commons.setup(glove_dir=glove_dir,
                      embedding_dim=embedding_dim,
                      dataset_size=dataset_size,
                      words_per_sentence=words_per_sentence)
models = create_models(setup, models_dir, history_dir)
# Out:
# Found 400000 word vectors.
# 17361/88587 unknown words

# %%
# evaluate history
def plot_metric(col_name, is_training=True, normalize=False):
    figure(num=None, figsize=(8, 4), dpi=80)

    for model in models:
        (history, last_epoch) = model.load_history()
        y_label = col_name

        if is_training:
            col = col_name
        else:
            col = "val_%s" % col_name
            y_label = col

        if normalize:
            norm_factor = 1./np.max(history[col][:50])
            y_label += (" (normalized)")
        else:
            norm_factor = 1.
            
        if model.is_variational():
            linestyle = "-"
            alpha = 1.0
        else:
            alpha = 0.6
            linestyle = "--"
            
        plt.plot(np.arange(1, epochs + 1, 1), history[col][:50] * norm_factor, alpha=alpha, linestyle=linestyle)


    plt.legend([model.readable_name() for model in models])
    plt.xlabel("epoch")
    plt.ylabel(y_label)
    plt.xlim([0, epochs + 1])
    plt.grid()
    plt.savefig(history_evaluation_folder + str(int(models[0].N)) + "_" + col + ".svg")
    plt.show()


plot_metric("loss", True, normalize=True)
plot_metric("loss", False, normalize=True)

for metric in ["acc", "recall", "precision", "kl"]:
    plot_metric(metric, True)
    plot_metric(metric, False)
# Out:
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 75
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50
# Loaded history successfully. Last epoch: 50

# %%
x_test, y_test = commons.load_imdb(0.25)[1]
x_test_padded = commons.pad_input(x_test, words_per_sentence)

# %%
def evaluate_datasizes(x_test_padded, y_test, data_sizes=[1.0, 0.8, 0.6, 0.4, 0.2, 0.1, 0.01]):
    y_N = []
    Ns = []
    for dataset_size in data_sizes:
        setup = commons.setup(glove_dir=glove_dir,
                              embedding_dim=embedding_dim,
                              dataset_size=dataset_size,
                              words_per_sentence=words_per_sentence)
        models = create_models(setup, models_dir, history_dir)
        N = models[0].N

        Ns += [N]
        y_Ni = []
        for model in models:
            evaluations = model.load_model().evaluate(x_test_padded, y_test)
            y_Ni += [evaluations]
        y_N += [y_Ni]
    
    return (Ns, y_N)

Ns, y_N = evaluate_datasizes(x_test_padded, y_test)
# Out:
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 702us/sample - loss: 0.4538 - acc: 0.8376 - true_negatives: 2574.0000 - false_negatives: 448.0000 - true_positives: 2661.0000 - false_positives: 567.0000 - precision: 0.8243 - recall: 0.8559 - kl: 0.1851
# using saved model
# 6250/6250 [==============================] - 6s 960us/sample - loss: 0.3340 - acc: 0.8557 - true_negatives: 2733.0000 - false_negatives: 494.0000 - true_positives: 2615.0000 - false_positives: 408.0000 - precision: 0.8650 - recall: 0.8411 - kl: 0.1783
# using saved model
# 6250/6250 [==============================] - 5s 825us/sample - loss: 0.4901 - acc: 0.7691 - true_negatives: 2247.0000 - false_negatives: 549.0000 - true_positives: 2560.0000 - false_positives: 894.0000 - precision: 0.7412 - recall: 0.8234 - kl: 0.2068
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 0.9557 - acc: 0.8408 - true_negatives: 2650.0000 - false_negatives: 504.0000 - true_positives: 2605.0000 - false_positives: 491.0000 - precision: 0.8414 - recall: 0.8379 - kl: 0.2021
# using saved model
# 6250/6250 [==============================] - 4s 718us/sample - loss: 1.1391 - acc: 0.8197 - true_negatives: 2572.0000 - false_negatives: 558.0000 - true_positives: 2551.0000 - false_positives: 569.0000 - precision: 0.8176 - recall: 0.8205 - kl: 0.2208
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 691us/sample - loss: 0.4856 - acc: 0.8178 - true_negatives: 2499.0000 - false_negatives: 497.0000 - true_positives: 2612.0000 - false_positives: 642.0000 - precision: 0.8027 - recall: 0.8401 - kl: 0.1995
# using saved model
# 6250/6250 [==============================] - 6s 971us/sample - loss: 0.3460 - acc: 0.8510 - true_negatives: 2636.0000 - false_negatives: 426.0000 - true_positives: 2683.0000 - false_positives: 505.0000 - precision: 0.8416 - recall: 0.8630 - kl: 0.1511
# using saved model
# 6250/6250 [==============================] - 5s 836us/sample - loss: 0.5008 - acc: 0.7670 - true_negatives: 2448.0000 - false_negatives: 763.0000 - true_positives: 2346.0000 - false_positives: 693.0000 - precision: 0.7720 - recall: 0.7546 - kl: 0.2718
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 1.3059 - acc: 0.8285 - true_negatives: 2658.0000 - false_negatives: 589.0000 - true_positives: 2520.0000 - false_positives: 483.0000 - precision: 0.8392 - recall: 0.8106 - kl: 0.2320
# using saved model
# 6250/6250 [==============================] - 5s 723us/sample - loss: 1.5354 - acc: 0.8051 - true_negatives: 2612.0000 - false_negatives: 689.0000 - true_positives: 2420.0000 - false_positives: 529.0000 - precision: 0.8206 - recall: 0.7784 - kl: 0.2687
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 691us/sample - loss: 0.5151 - acc: 0.8064 - true_negatives: 2580.0000 - false_negatives: 649.0000 - true_positives: 2460.0000 - false_positives: 561.0000 - precision: 0.8143 - recall: 0.7913 - kl: 0.2397
# using saved model
# 6250/6250 [==============================] - 6s 961us/sample - loss: 0.3642 - acc: 0.8363 - true_negatives: 2516.0000 - false_negatives: 398.0000 - true_positives: 2711.0000 - false_positives: 625.0000 - precision: 0.8126 - recall: 0.8720 - kl: 0.1494
# using saved model
# 6250/6250 [==============================] - 5s 832us/sample - loss: 0.5159 - acc: 0.7547 - true_negatives: 2428.0000 - false_negatives: 820.0000 - true_positives: 2289.0000 - false_positives: 713.0000 - precision: 0.7625 - recall: 0.7362 - kl: 0.2790
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 1.6321 - acc: 0.8098 - true_negatives: 2418.0000 - false_negatives: 466.0000 - true_positives: 2643.0000 - false_positives: 723.0000 - precision: 0.7852 - recall: 0.8501 - kl: 0.1818
# using saved model
# 6250/6250 [==============================] - 5s 720us/sample - loss: 1.9192 - acc: 0.7936 - true_negatives: 2581.0000 - false_negatives: 730.0000 - true_positives: 2379.0000 - false_positives: 560.0000 - precision: 0.8095 - recall: 0.7652 - kl: 0.2860
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 709us/sample - loss: 0.5896 - acc: 0.7883 - true_negatives: 2453.0000 - false_negatives: 635.0000 - true_positives: 2474.0000 - false_positives: 688.0000 - precision: 0.7824 - recall: 0.7958 - kl: 0.2574
# using saved model
# 6250/6250 [==============================] - 6s 955us/sample - loss: 0.3875 - acc: 0.8320 - true_negatives: 2610.0000 - false_negatives: 519.0000 - true_positives: 2590.0000 - false_positives: 531.0000 - precision: 0.8299 - recall: 0.8331 - kl: 0.1899
# using saved model
# 6250/6250 [==============================] - 5s 835us/sample - loss: 0.5374 - acc: 0.7526 - true_negatives: 2258.0000 - false_negatives: 663.0000 - true_positives: 2446.0000 - false_positives: 883.0000 - precision: 0.7348 - recall: 0.7867 - kl: 0.2503
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 2.9639 - acc: 0.7963 - true_negatives: 2437.0000 - false_negatives: 569.0000 - true_positives: 2540.0000 - false_positives: 704.0000 - precision: 0.7830 - recall: 0.8170 - kl: 0.2213
# using saved model
# 6250/6250 [==============================] - 5s 731us/sample - loss: 3.5384 - acc: 0.7712 - true_negatives: 2328.0000 - false_negatives: 617.0000 - true_positives: 2492.0000 - false_positives: 813.0000 - precision: 0.7540 - recall: 0.8015 - kl: 0.2352
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 699us/sample - loss: 0.7135 - acc: 0.7677 - true_negatives: 2361.0000 - false_negatives: 672.0000 - true_positives: 2437.0000 - false_positives: 780.0000 - precision: 0.7575 - recall: 0.7839 - kl: 0.2679
# using saved model
# 6250/6250 [==============================] - 6s 980us/sample - loss: 0.4200 - acc: 0.8077 - true_negatives: 2426.0000 - false_negatives: 487.0000 - true_positives: 2622.0000 - false_positives: 715.0000 - precision: 0.7857 - recall: 0.8434 - kl: 0.1834
# using saved model
# 6250/6250 [==============================] - 5s 841us/sample - loss: 0.5950 - acc: 0.7178 - true_negatives: 2094.0000 - false_negatives: 717.0000 - true_positives: 2392.0000 - false_positives: 1047.0000 - precision: 0.6956 - recall: 0.7694 - kl: 0.2542
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 20.3586 - acc: 0.7746 - true_negatives: 2457.0000 - false_negatives: 725.0000 - true_positives: 2384.0000 - false_positives: 684.0000 - precision: 0.7771 - recall: 0.7668 - kl: 0.2881
# using saved model
# 6250/6250 [==============================] - 5s 745us/sample - loss: 21.7773 - acc: 0.7320 - true_negatives: 2357.0000 - false_negatives: 891.0000 - true_positives: 2218.0000 - false_positives: 784.0000 - precision: 0.7388 - recall: 0.7134 - kl: 0.3566
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 4s 711us/sample - loss: 0.8673 - acc: 0.7286 - true_negatives: 2350.0000 - false_negatives: 905.0000 - true_positives: 2204.0000 - false_positives: 791.0000 - precision: 0.7359 - recall: 0.7089 - kl: 0.3510
# using saved model
# 6250/6250 [==============================] - 6s 979us/sample - loss: 0.4902 - acc: 0.7762 - true_negatives: 2562.0000 - false_negatives: 820.0000 - true_positives: 2289.0000 - false_positives: 579.0000 - precision: 0.7981 - recall: 0.7362 - kl: 0.2756
# using saved model
# 6250/6250 [==============================] - 5s 858us/sample - loss: 0.6634 - acc: 0.6797 - true_negatives: 2152.0000 - false_negatives: 1013.0000 - true_positives: 2096.0000 - false_positives: 989.0000 - precision: 0.6794 - recall: 0.6742 - kl: 0.3424
# using saved model
# 6250/6250 [==============================] - 9s 1ms/sample - loss: 69.6882 - acc: 0.7323 - true_negatives: 2205.0000 - false_negatives: 737.0000 - true_positives: 2372.0000 - false_positives: 936.0000 - precision: 0.7170 - recall: 0.7629 - kl: 0.3365
# using saved model
# 6250/6250 [==============================] - 5s 744us/sample - loss: 70.5978 - acc: 0.6754 - true_negatives: 1943.0000 - false_negatives: 831.0000 - true_positives: 2278.0000 - false_positives: 1198.0000 - precision: 0.6554 - recall: 0.7327 - kl: 0.3093
# Found 400000 word vectors.
# 17361/88587 unknown words
# using saved model
# 6250/6250 [==============================] - 5s 728us/sample - loss: 1.6291 - acc: 0.5454 - true_negatives: 1957.0000 - false_negatives: 1657.0000 - true_positives: 1452.0000 - false_positives: 1184.0000 - precision: 0.5508 - recall: 0.4670 - kl: 0.6019
# using saved model
# 6250/6250 [==============================] - 6s 1ms/sample - loss: 0.6693 - acc: 0.6408 - true_negatives: 1489.0000 - false_negatives: 593.0000 - true_positives: 2516.0000 - false_positives: 1652.0000 - precision: 0.6036 - recall: 0.8093 - kl: 0.2137
# using saved model
# 6250/6250 [==============================] - 6s 901us/sample - loss: 0.7119 - acc: 0.5131 - true_negatives: 1742.0000 - false_negatives: 1644.0000 - true_positives: 1465.0000 - false_positives: 1399.0000 - precision: 0.5115 - recall: 0.4712 - kl: 0.3711
# using saved model
# 6250/6250 [==============================] - 10s 2ms/sample - loss: 1016.0394 - acc: 0.5285 - true_negatives: 2035.0000 - false_negatives: 1841.0000 - true_positives: 1268.0000 - false_positives: 1106.0000 - precision: 0.5341 - recall: 0.4078 - kl: 0.4669
# using saved model
# 6250/6250 [==============================] - 7s 1ms/sample - loss: 1016.9208 - acc: 0.5038 - true_negatives: 1908.0000 - false_negatives: 1868.0000 - true_positives: 1241.0000 - false_positives: 1233.0000 - precision: 0.5016 - recall: 0.3992 - kl: 0.4755

# %%
metric_names = models[0].load_model().metrics_names
y_N = np.array(y_N)

for i in range(len(models)):
    evaluation = y_N_new[:,i]
    df = pd.DataFrame(evaluation, columns=metric_names)
    df["N"] = Ns
    df.to_csv(history_evaluation_folder + models[i].model_id() + "_varrying_n.csv", sep=";")
# Out:
# using saved model

# %%
for i in range(len(metric_names)):
    metric = metric_names[i]
    figure(num=None, figsize=(8, 4), dpi=80)
    for m in range(len(models)):
        model = models[m]
        y_label = metric

        if model.is_variational():
            linestyle = "-"
            alpha = 1.0
        else:
            alpha = 0.6
            linestyle = "--"
        
        if metric == "loss" or metric == "val_loss":
            norm_factor = 1./np.max(y_N[:,m,i])
        else:
            norm_factor = 1.

        plt.plot(Ns, y_N[:,m,i] * norm_factor, alpha=alpha, linestyle=linestyle)   
        
    if metric == "loss" or metric == "val_loss":
        y_label += (" (normalized)")
        
    plt.legend([model.readable_name() for model in models])
    plt.xlabel("data size")
    plt.ylabel(y_label)
    plt.grid()
    plt.savefig(history_evaluation_folder + str(int(models[0].N)) + "_" + metric + "_varrying_n" + ".svg")
    plt.show()
